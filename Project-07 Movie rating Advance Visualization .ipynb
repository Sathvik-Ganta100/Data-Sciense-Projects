# %% [markdown]
# # Project-7  Movie rating Advance Visualization

# %%
import pandas as pd

# %%
movies = pd.read_csv(r'D:\1. Professionall\Data Science\07-25,26-2023\Movie-Rating.csv')

movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns = ['Film', 'Genre', 'CriticRating', 'AudienceRating','BudgetMillions','Year']

                  # removing noise characters in dataframe

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies['Film'] = movies['Film'].astype('category')          # Chainging Data types of attributes

movies['Genre'] = movies['Genre'].astype('category')

# %%
movies.info()   # now dtype chainged to category
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: category(2), int64(4)
# memory usage: 40.1 KB

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
movies['Year'] = movies['Year'].astype('category')  # since movie should not be considered in descriptive statistics

# %%
movies.describe()   # year column is gone
# Out:
#        CriticRating  AudienceRating  BudgetMillions
# count    559.000000      559.000000      559.000000
# mean      47.309481       58.744186       50.236136
# std       26.413091       16.826887       48.731817
# min        0.000000        0.000000        0.000000
# 25%       25.000000       47.000000       20.000000
# 50%       46.000000       58.000000       35.000000
# 75%       70.000000       72.000000       65.000000
# max       97.000000       96.000000      300.000000

# %% [markdown]
# ## working with joint plots
#
# * basically joint plot is a scatter plot & it find the relation b/w audiene & critics
# * also if you look up you can find the uniform distribution (critics)and normal distriution (audience)

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
j = sns.jointplot(data = movies, x = 'CriticRating', y = 'AudienceRating')

# %%
j = sns.jointplot( data = movies, x = 'CriticRating', y = 'AudienceRating', kind='hex')

# %%
j = sns.jointplot( data = movies, x = 'CriticRating', y = 'AudienceRating', kind='kde')

# %%
j = sns.jointplot( data = movies, x = 'CriticRating', y = 'AudienceRating', kind='reg')

# %%
j = sns.jointplot( data = movies, x = 'CriticRating', y = 'AudienceRating', hue = 'Genre')

# %%
j = sns.jointplot( data = movies, x = 'CriticRating', y = 'AudienceRating', kind='resid')

# %% [markdown]
# ## Histograms

# %%
m1 = sns.distplot(movies.AudienceRating)

# %%
m2 = sns.distplot(movies.CriticRating)

# %%
sns.set_style('darkgrid')   # other styles  (darkgrid, whitegrid, dark, white, ticks)

# %%
m1 = sns.distplot(movies.AudienceRating, bins = 15)

# %%
sns.set_style('white')

n2 = plt.hist(movies.CriticRating, bins=20)

# %%
plt.hist(movies.BudgetMillions)

plt.show()

# %%
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillions)

plt.show()

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.Genre.unique()
# Out:
# ['Comedy', 'Adventure', 'Action', 'Horror', 'Drama', 'Romance', 'Thriller']
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
plt.hist(movies[movies.Genre == 'Action'].BudgetMillions, bins = 20, label='Action')
plt.hist(movies[movies.Genre == 'Drama'].BudgetMillions, bins = 20, label='Drama')
plt.hist(movies[movies.Genre == 'Thriller'].BudgetMillions, bins = 20, label='Thriller')

plt.legend()
plt.show()

# %%
plt.hist([movies[movies.Genre == 'Action'].BudgetMillions,\
          movies[movies.Genre == 'Drama'].BudgetMillions, \
          movies[movies.Genre == 'Thriller'].BudgetMillions, \
          movies[movies.Genre == 'Comedy'].BudgetMillions],
         bins = 20, stacked = True)
plt.show()

# %% [markdown]
# ## Lenear Model Plot (lm plot)

# %%
vis1 = sns.lmplot(data=movies, x='CriticRating', y='AudienceRating', fit_reg=False)

# %%
vis1 = sns.lmplot(data=movies, x='CriticRating', y='AudienceRating', fit_reg=False, hue = 'Genre')

# %%
vis1 = sns.lmplot(data=movies, x='CriticRating', y='AudienceRating', fit_reg=True, hue = 'Genre')

# %%
sns.set_style('dark',{'axes.facecolor':'black'})

vis1 = sns.lmplot(data=movies, x='CriticRating', y='AudienceRating', fit_reg=False, hue = 'Genre',height = 7)

# %% [markdown]
# ## Kernal Density Estimate plot ( KDE PLOT)

# %%
sns.set_style('white')
    
k1 = sns.kdeplot(data = movies, x = 'CriticRating', y = 'AudienceRating')

# %%
f, axes = plt.subplots(1,2, figsize=(12,6))

k2 = sns.kdeplot(data = movies, x = 'CriticRating', y = 'AudienceRating',shade = True,shade_lowest=False,cmap='Reds',ax=axes[0])
k3 = sns.kdeplot(data = movies, x = 'CriticRating', y = 'AudienceRating',shade_lowest=False,cmap='Greens_r',ax=axes[1])

# %%
sns.set_style('darkgrid')

f, axes = plt.subplots(1,2, figsize=(12,6))

k1 = sns.kdeplot(data = movies, x = 'BudgetMillions', y = 'AudienceRating',shade_lowest=False,cmap='Greens_r', ax=axes[0])
k1 = sns.kdeplot(data = movies, x = 'BudgetMillions', y = 'AudienceRating', ax=axes[1])

# %%
k1 = sns.kdeplot(data = movies, x = 'BudgetMillions', y = 'CriticRating')

# %% [markdown]
# ## subplots

# %%
#f, ax = plt.subplots(1,2, figsize =(12,6))
f, ax = plt.subplots(3,3, figsize =(12,6))   # (row, col) ---> (3,3) = 3 x 3 = 9 figures

# %%
axes   # gives info about last axes fig
# Out:
# array([<Axes: xlabel='BudgetMillions', ylabel='AudienceRating'>,
#        <Axes: xlabel='BudgetMillions', ylabel='AudienceRating'>],
#       dtype=object)

# %% [markdown]
# ## Box plots

# %%
sns.set_style('dark',{'axes.facecolor':'black'})

w = sns.boxplot(data=movies, x='Genre', y = 'CriticRating')

# %%
sns.set_style('dark')

z = sns.violinplot(data=movies, x='Genre', y = 'CriticRating')

# %%
w1 = sns.boxplot(data=movies[movies.Genre == 'Drama'], x='Year', y = 'CriticRating')

# %%
z1 = sns.violinplot(data=movies[movies.Genre == 'Drama'], x='Year', y = 'CriticRating')

# %% [markdown]
# ##  Facet grid creation

# %%
g =sns.FacetGrid (movies, row = 'Genre', col = 'Year', hue = 'Genre')     #  a kind of subplots

# %%
sns.set_style('dark',{'axes.facecolor':'black'})

plt.scatter(movies.CriticRating,movies.AudienceRating)

# %%
sns.set_style('dark')

g =sns.FacetGrid (movies, row = 'Genre', col = 'Year', hue = 'Genre')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating' )                  #scatterplots are mapped in facetgrid

# %%
g =sns.FacetGrid (movies, row = 'Genre', col = 'Year', hue = 'Genre')
g = g.map(plt.hist, 'BudgetMillions' )

# %%
sns.set_style('dark',{'axes.facecolor':'black'})

g =sns.FacetGrid (movies, row = 'Genre', col = 'Year', hue = 'Genre')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRating')

# %%
sns.set_style('dark',{'axes.facecolor':'black'})
f, axes = plt.subplots(2,2, figsize=(10,10))

k1 =sns.kdeplot(data=movies, x='BudgetMillions', y='AudienceRating', ax=axes[0,0])
k2 =sns.kdeplot(data=movies, x='BudgetMillions', y='CriticRating', ax=axes[0,1])

s = sns.violinplot(data= movies[movies.Genre=='Drama'], x='Year', y='CriticRating', ax = axes[1,0])
k3 = sns.kdeplot(data = movies, x='CriticRating', y='AudienceRating', shade=True, shade_lowest= False, cmap='Reds',ax=axes[1,1])

plt.show()

# %%
# How can you style your dashboard  using different color map

# python is not vectorize programming language
# Building dashboards (dashboard - combination of chats)

#sns.set_style('dark',{'axes.facecolor':'black'})
f, axes = plt.subplots (2,2, figsize = (10,10))

#plot [0,0]
k1 = sns.kdeplot(data=movies,x='BudgetMillions',y='AudienceRating',shade = True, shade_lowest=False,cmap = 'cool',ax = axes[0,0])
k1b = sns.kdeplot(data=movies, x='BudgetMillions', y='AudienceRating',cmap = 'cool',ax = axes[0,0])

#plot [0,1]
k2 = sns.kdeplot(data=movies,x='BudgetMillions',y='CriticRating',shade=True, shade_lowest=True, cmap='inferno',ax = axes[0,1])
k2b = sns.kdeplot(data=movies,x='BudgetMillions',y='CriticRating',cmap = 'cool', ax = axes[0,1])

#plot[1,0]
z = sns.violinplot(data=movies[movies.Genre=='Drama'],x='Year', y = 'CriticRating', ax=axes[1,0])

#plot[1,1]
k4 = sns.kdeplot(data=movies, x='CriticRating',y='AudienceRating',shade = True,shade_lowest=False,cmap='Blues_r',ax=axes[1,1])
k4b = sns.kdeplot(data=movies,x='CriticRating', y='AudienceRating',cmap='gist_gray_r',ax = axes[1,1])

#k1.set(xlim=(-20,160))
#k2.set(xlim=(-20,160))

plt.show()

# %% [markdown]
# ## What we learn so far
#
# 1. category datatype in python
# 2. jointplots
# 3. histogram
# 4. stacked histograms
# 5. LM plot
# 6. Kde plot
# 7. subplot
# 8. violin plots
# 9. Factet grid
# 10. Building dashboards
