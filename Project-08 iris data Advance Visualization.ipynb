# %% [markdown]
# # IRIS data Advance Visualization

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
  
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1. Displaying data

# %%
iris = pd.read_csv(r'D:\1. Professionall\Data Science\07-25,26-2023\iris.csv')

iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
iris.drop('Id',axis=1,inplace=True)

# %%
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
iris['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %% [markdown]
# ## 2. Bar plot

# %%
sns.countplot(data = iris, x = 'Species')
# Out:
# <Axes: xlabel='Species', ylabel='count'>

# %% [markdown]
# ## 3. Joint plot

# %%
fig1 = sns.jointplot(data= iris, x = 'SepalLengthCm', y = 'SepalWidthCm')

# %%
fig2 = sns.jointplot(data= iris, x = 'SepalLengthCm', y = 'SepalWidthCm', kind = 'reg')

# %%
fig3 = sns.jointplot(data= iris, x = 'SepalLengthCm', y = 'SepalWidthCm', kind = 'hex')

# %%
fig4 = sns.jointplot(data= iris, x = 'SepalLengthCm', y = 'SepalWidthCm', hue = 'Species')

# %%
fig5 = sns.jointplot(data= iris, x = 'SepalLengthCm', y = 'SepalWidthCm', hue = 'Species', kind = 'kde')

# %%
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ## 4. Facetgrid plot

# %%
sns.FacetGrid(iris,hue='Species', height = 5).map(plt.scatter,'SepalLengthCm','SepalWidthCm').add_legend()

# %%
sns.FacetGrid(iris, hue='Species', height = 5).map(plt.scatter, 'PetalLengthCm','PetalWidthCm').add_legend()

# %% [markdown]
# ## 5. Box plot

# %%
fig=sns.boxplot(data=iris, x='Species' ,y='PetalLengthCm', order=['Iris-virginica','Iris-versicolor','Iris-setosa'], orient='v')

# %%
iris.boxplot(by = "Species", figsize = (12, 6))
# Out:
# array([[<Axes: title={'center': 'PetalLengthCm'}, xlabel='[Species]'>,
#         <Axes: title={'center': 'PetalWidthCm'}, xlabel='[Species]'>],
#        [<Axes: title={'center': 'SepalLengthCm'}, xlabel='[Species]'>,
#         <Axes: title={'center': 'SepalWidthCm'}, xlabel='[Species]'>]],
#       dtype=object)

# %% [markdown]
# ## 6. Strip plot

# %%
fig=plt.gcf()
fig.set_size_inches(7, 5)
fig=sns.stripplot(data=iris, x='Species', y='SepalLengthCm', jitter=True, edgecolor='gray', size=8, palette='winter',orient='v')

# %% [markdown]
# ## 7. Combining Box and Strip Plots

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.boxplot(data = iris, x = 'Species', y = 'SepalLengthCm')
fig=sns.stripplot(data = iris, x = 'Species', y = 'SepalLengthCm', hue = 'Species')

# %%
colors = ['green', 'red', 'yellow']

sns.boxplot(data = iris, x = "Species", y = "PetalLengthCm", palette = colors)
sns.stripplot(data = iris, x = "Species", y = "PetalLengthCm", jitter = True, hue = 'Species')



plt.show()

# %% [markdown]
# ## 8. Violin Plot

# %%
fig=sns.violinplot(data = iris, x = 'Species', y = 'SepalLengthCm')

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.violinplot(data = iris, x = 'Species', y = 'PetalLengthCm')
plt.subplot(2,2,2)
sns.violinplot(data = iris, x = 'Species', y = 'PetalWidthCm')
plt.subplot(2,2,3)
sns.violinplot(data = iris, x = 'Species', y = 'SepalLengthCm')
plt.subplot(2,2,4)
sns.violinplot(data = iris, x = 'Species', y = 'SepalWidthCm')
# Out:
# <Axes: xlabel='Species', ylabel='SepalWidthCm'>

# %% [markdown]
# ## 9. Pair Plot

# %%
sns.pairplot(data = iris, kind = 'scatter')

# %%
sns.pairplot(data = iris, hue = 'Species')

# %% [markdown]
# ## 10. Heat map

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.heatmap(iris.corr(),annot=True,cmap='cubehelix',linewidths=1,linecolor='k',
                square=True,mask=False, vmin=-1, vmax=1,cbar_kws={"orientation": "vertical"},cbar=True)

# %% [markdown]
# ## 11. Distribution plot

# %%
iris.hist(edgecolor = 'black', linewidth = 1.2)
fig=plt.gcf()
fig.set_size_inches(12,6)

# %% [markdown]
# ## 12. Swarm plot

# %%
fig = sns.swarmplot(data=iris, x = "Species", y = "PetalLengthCm",  hue = 'Species')

# %%
sns.set(style="whitegrid")
fig = plt.gcf()
fig.set_size_inches(9,7)
ax = sns.violinplot(data = iris, x = "Species", y = "PetalLengthCm", inner = None)
ax = sns.swarmplot(data = iris, x = "Species", y = "PetalLengthCm", color = "white", edgecolor = "black")

# %% [markdown]
# ## 13. Lm plot

# %%
fig = sns.lmplot(data = iris, x = "PetalLengthCm", y = "PetalWidthCm")

# %%
fig = sns.lmplot(data=iris, x = "SepalLengthCm", y = "SepalWidthCm")

# %% [markdown]
# ## 14. FacetGrid

# %%
sns.FacetGrid(iris, hue="Species", height = 6).map(sns.kdeplot, "PetalLengthCm").add_legend()
plt.show()

# %% [markdown]
# ## 15. Factor Plot

# %%
sns.set_style('darkgrid')

sns.catplot(data=iris, x = 'Species', y = 'SepalLengthCm', kind ="point")
#plt.ioff()        # the plots will not be displayed immediately ew should use show comand every time
plt.show()

# %% [markdown]
# ## 16. plt.ioff()
#
# **plt.ioff()** = the plots will not be displayed immediately we should use plt.show() comand every time after this

# %% [markdown]
# ## 17. Boxen plot

# %%
sns.set_style('whitegrid')

fig=plt.gcf()
fig.set_size_inches(7, 5)
fig=sns.boxenplot(data = iris, x = 'Species', y = 'SepalLengthCm')

# %% [markdown]
# ## 18. KDE Plot

# %%
sub = iris[iris['Species'] == 'Iris-setosa']

sns.kdeplot(data=sub , x='SepalLengthCm', y='SepalWidthCm', cmap="plasma", shade=True, shade_lowest=False, cbar=True)

plt.title('Iris-setosa')
plt.xlabel('Sepal Length Cm')
plt.ylabel('Sepal Width Cm')

plt.show()

# %% [markdown]
# ## 19. Dashboard

# %%
sns.set_style('darkgrid')
f,axes=plt.subplots(2,2,figsize=(10,10))

k1=sns.boxplot(data=iris,x="Species", y="PetalLengthCm",ax=axes[0,0])
k2=sns.violinplot(data=iris,x='Species',y='PetalLengthCm',ax=axes[0,1])
k3=sns.stripplot(data=iris,x='Species',y='SepalLengthCm',jitter=True,edgecolor='gray',palette='winter',orient='v',ax=axes[1,0])
axes[1,1].hist(iris.PetalLengthCm,bins=10)

plt.show()

# %% [markdown]
# ## 20. Stacked Histogram

# %%
iris['Species'] = iris['Species'].astype('category')

iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    category
# dtypes: category(1), float64(4)
# memory usage: 5.1 KB

# %%
list1=list()
mylabels=list()
for gen in iris.Species.cat.categories:
    list1.append(iris[iris.Species==gen].SepalLengthCm)
    mylabels.append(gen)
    
h=plt.hist(list1,bins=30,stacked=True,rwidth=1,label=mylabels)

plt.legend()
plt.show()

# %%
## 21. Area plot

# %%
iris.plot.area(y=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm'],alpha=0.4,figsize=(12, 6))
# Out:
# <Axes: >

# %% [markdown]
# ## 22. Distplot

# %%
sns.distplot(iris['SepalLengthCm'],kde=True,bins=20)
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='Density'>

# %% [markdown]
# ## What we learned
#
# 1. Displaying data
# 2. Bar plot
# 3. Joint plot
# 4. Facetgrid plot
# 5. Box plot
# 6. Strip plot
# 7. Combining Box and Strip Plots
# 8. Violin Plot
# 9. Pair Plot
# 10. Heat map
# 11. Distribution plot
# 12. Swarm plot
# 13. Lm plot
# 14. FacetGrid
# 15. Factor Plot
# 16. plt.ioff()
# 17. Boxen plot
# 18. KDE Plot
# 19. Dashboard
# 20. Stacked Histogram
# 21. Area plot
# 22. Distplot
